# %%
from fontTools.misc.arrayTools import pointInRect

day = 6
match day:
    case 1:
        print("Day 1")
    case 2:
        print("Day 2")
    case 3:
        print("Day 3")
    case 4:
        print("Day 4")
    case _:
        print("Nothing matching")
# Out:
# Nothing matching

# %%
month = 5
day = 4
match day:
    case 1|2|3|4 if month == 5:
        print("A weekday in may")
# Out:
# A weekday in may

# %%
import  datetime
x = datetime.datetime.now()
print(x)
print(x.year)
print(x.strftime("%D"))
time = datetime.datetime(2020, 5, 17)
print(time)
# Out:
# 2026-03-01 13:58:43.970284
# 2026
# 03/01/26
# 2020-05-17 00:00:00

# %%
import json

x = '{"name":"Suman","age":30,"city":"Barishal"}'
y = json.loads(x)
print(y["age"])
print(y)
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}

y = json.dumps(x)
print(y)
# Out:
# 30
# {'name': 'Suman', 'age': 30, 'city': 'Barishal'}
# {"name": "John", "age": 30, "city": "New York"}

# %%
class Student:
    x = 5
sumon = Student()
print(sumon.x)
# Out:
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 5
#       3 sumon = Student()
#       4 print(sumon.x)
# ----> 5 del sumon.x
#       6 print(sumon.x)
#
# AttributeError: 'Student' object has no attribute 'x'
